# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv("addresses.csv")
df.columns
df.head()
# Out:
#    borough   neighborhood               building_category  block_id  lot_id  \
# 0      1.0  ALPHABET CITY       03 THREE FAMILY DWELLINGS     377.0    66.0
# 1      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    23.0
# 2      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    26.0
# 3      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
# 4      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
#
#                       address  zip_code  res_units  comm_units  total_units  \
# 0         243 EAST 7TH STREET   10009.0        3.0         0.0          3.0
# 1      262 EAST 7TH STREET, 4   10009.0        4.0         0.0          4.0
# 2         268 EAST 7TH STREET   10009.0        4.0         0.0          4.0
# 3  278 EAST 7TH STREET, 1B/2B   10009.0       19.0         0.0         19.0
# 4  278 EAST 7TH STREET, 1C/1D   10009.0       19.0         0.0         19.0
#
#   square_ft  year_built  tax_class building_class_id  sale_price   sale_date  \
# 0     2,381      1899.0        1.0                C0     4350000   7/16/2020
# 1     2,059      1900.0        2.0                C3      600000  12/12/2019
# 2     2,065      1900.0        2.0                C3     4350000  10/31/2019
# 3     2,772      1920.0        2.0                C4      290000    2/7/2020
# 4     2,772      1920.0        2.0                C4        2500   2/11/2020
#
#    longitude   latitude
# 0  40.723987 -73.978167
# 1  40.723384 -73.977590
# 2  40.723276 -73.977386
# 3  40.723106 -73.977057
# 4  40.723106 -73.977057

# %%
df.borough.value_counts()
# Out:
# 4.0    13902
# 3.0    11909
# 1.0    10432
# 2.0     4196
# 5.0     4162
# Name: borough, dtype: int64

# %%
df.building_category.value_counts()
# Out:
# 01 ONE FAMILY DWELLINGS                       9801
# 10 COOPS - ELEVATOR APARTMENTS                8773
# 02 TWO FAMILY DWELLINGS                       7384
# 13 CONDOS - ELEVATOR APARTMENTS               6842
# 09 COOPS - WALKUP APARTMENTS                  1769
# 03 THREE FAMILY DWELLINGS                     1623
# 07 RENTALS - WALKUP APARTMENTS                1048
# 15 CONDOS - 2-10 UNIT RESIDENTIAL              996
# 04 TAX CLASS 1 CONDOS                          964
# 44 CONDO PARKING                               777
# 17 CONDO COOPS                                 728
# 12 CONDOS - WALKUP APARTMENTS                  682
# 05 TAX CLASS 1 VACANT LAND                     469
# 22 STORE BUILDINGS                             425
# 29 COMMERCIAL GARAGES                          272
# 43 CONDO OFFICE BUILDINGS                      248
# 14 RENTALS - 4-10 UNIT                         207
# 21 OFFICE BUILDINGS                            199
# 47 CONDO NON-BUSINESS STORAGE                  197
# 08 RENTALS - ELEVATOR APARTMENTS               173
# 31 COMMERCIAL VACANT LAND                      154
# 30 WAREHOUSES                                  151
# 41 TAX CLASS 4 - OTHER                         101
# 27 FACTORIES                                    97
# 46 CONDO STORE BUILDINGS                        83
# 06 TAX CLASS 1 - OTHER                          81
# 37 RELIGIOUS FACILITIES                         57
# 45 CONDO HOTELS                                 45
# 11 SPECIAL CONDO BILLING LOTS                   36
# 16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT      33
# 32 HOSPITAL AND HEALTH FACILITIES               30
# 28 COMMERCIAL CONDOS                            24
# 33 EDUCATIONAL FACILITIES                       22
# 36 OUTDOOR RECREATIONAL FACILITIES              18
# 48 CONDO TERRACES/GARDENS/CABANAS               14
# 38 ASYLUMS AND HOMES                            13
# 26 OTHER HOTELS                                 13
# 42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC       13
# 25 LUXURY HOTELS                                13
# 35 INDOOR PUBLIC AND CULTURAL FACILITIES        11
# 49 CONDO WAREHOUSES/FACTORY/INDUS                7
# 39 TRANSPORTATION FACILITIES                     4
# 34 THEATRES                                      3
# 23 LOFT BUILDINGS                                1
# Name: building_category, dtype: int64

# %%
df.neighborhood.value_counts()
# Out:
# FLUSHING-NORTH              1341
# UPPER EAST SIDE (59-79)     1005
# UPPER WEST SIDE (59-79)      951
# UPPER EAST SIDE (79-96)      894
# BEDFORD STUYVESANT           717
#                             ...
# CITY ISLAND-PELHAM STRIP       3
# BLOOMFIELD                     2
# AIRPORT JFK                    1
# BRONX PARK                     1
# CO-OP CITY                     1
# Name: neighborhood, Length: 252, dtype: int64

# %%
df['age'] = 2020 - df['year_built'] 
df.head()
# Out:
#    borough   neighborhood               building_category  block_id  lot_id  \
# 0      1.0  ALPHABET CITY       03 THREE FAMILY DWELLINGS     377.0    66.0
# 1      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    23.0
# 2      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    26.0
# 3      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
# 4      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
#
#                       address  zip_code  res_units  comm_units  total_units  \
# 0         243 EAST 7TH STREET   10009.0        3.0         0.0          3.0
# 1      262 EAST 7TH STREET, 4   10009.0        4.0         0.0          4.0
# 2         268 EAST 7TH STREET   10009.0        4.0         0.0          4.0
# 3  278 EAST 7TH STREET, 1B/2B   10009.0       19.0         0.0         19.0
# 4  278 EAST 7TH STREET, 1C/1D   10009.0       19.0         0.0         19.0
#
#   square_ft  year_built  tax_class building_class_id  sale_price   sale_date  \
# 0     2,381      1899.0        1.0                C0     4350000   7/16/2020
# 1     2,059      1900.0        2.0                C3      600000  12/12/2019
# 2     2,065      1900.0        2.0                C3     4350000  10/31/2019
# 3     2,772      1920.0        2.0                C4      290000    2/7/2020
# 4     2,772      1920.0        2.0                C4        2500   2/11/2020
#
#    longitude   latitude    age
# 0  40.723987 -73.978167  121.0
# 1  40.723384 -73.977590  120.0
# 2  40.723276 -73.977386  120.0
# 3  40.723106 -73.977057  100.0
# 4  40.723106 -73.977057  100.0

# %%
df = df.rename(columns = {'latitude': 'longitude', 'longitude': 'latitude'})
df.head()
# Out:
#    borough   neighborhood               building_category  block_id  lot_id  \
# 0      1.0  ALPHABET CITY       03 THREE FAMILY DWELLINGS     377.0    66.0
# 1      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    23.0
# 2      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    26.0
# 3      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
# 4      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
#
#                       address  zip_code  res_units  comm_units  total_units  \
# 0         243 EAST 7TH STREET   10009.0        3.0         0.0          3.0
# 1      262 EAST 7TH STREET, 4   10009.0        4.0         0.0          4.0
# 2         268 EAST 7TH STREET   10009.0        4.0         0.0          4.0
# 3  278 EAST 7TH STREET, 1B/2B   10009.0       19.0         0.0         19.0
# 4  278 EAST 7TH STREET, 1C/1D   10009.0       19.0         0.0         19.0
#
#   square_ft  year_built  tax_class building_class_id  sale_price   sale_date  \
# 0     2,381      1899.0        1.0                C0     4350000   7/16/2020
# 1     2,059      1900.0        2.0                C3      600000  12/12/2019
# 2     2,065      1900.0        2.0                C3     4350000  10/31/2019
# 3     2,772      1920.0        2.0                C4      290000    2/7/2020
# 4     2,772      1920.0        2.0                C4        2500   2/11/2020
#
#     latitude  longitude    age
# 0  40.723987 -73.978167  121.0
# 1  40.723384 -73.977590  120.0
# 2  40.723276 -73.977386  120.0
# 3  40.723106 -73.977057  100.0
# 4  40.723106 -73.977057  100.0

# %%
import geopy.distance
from geopy.distance import lonlat, distance
from tqdm import tqdm
tqdm.pandas()

central_park = (40.785091, -73.968285)
df['distance'] = df.progress_apply(lambda row: geopy.distance.great_circle(central_park, (row.latitude, row.longitude)).km, axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tqdm\std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
#
#
#
#
#
#
#
#
#
#
#   0%|                                                                                        | 0/44601 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|                                                                              | 1/44601 [00:00<1:22:09,  9.05it/s]
#
#
#
#
#
#
#
#
#
#   2%|█▍                                                                            | 808/44601 [00:00<56:29, 12.92it/s]
#
#
#
#
#
#
#
#
#
#   4%|███▏                                                                         | 1822/44601 [00:00<38:39, 18.45it/s]
#
#
#
#
#
#
#
#
#
#   6%|████▊                                                                        | 2766/44601 [00:00<26:28, 26.33it/s]
#
#
#
#
#
#
#
#
#
#   8%|██████▎                                                                      | 3634/44601 [00:00<18:10, 37.56it/s]
#
#
#
#
#
#
#
#
#
#  10%|███████▌                                                                     | 4358/44601 [00:00<12:31, 53.54it/s]
#
#
#
#
#
#
#
#
#
#  12%|█████████▏                                                                   | 5295/44601 [00:00<08:35, 76.30it/s]
#
#
#
#
#
#
#
#
#
#  14%|██████████▍                                                                 | 6151/44601 [00:00<05:54, 108.59it/s]
#
#
#
#
#
#
#
#
#
#  16%|████████████                                                                | 7112/44601 [00:00<04:02, 154.38it/s]
#
#
#
#
#
#
#
#
#
#  18%|█████████████▌                                                              | 7959/44601 [00:01<02:47, 218.82it/s]
#
#
#
#
#
#
#
#
#
#  20%|███████████████                                                             | 8852/44601 [00:01<01:55, 309.35it/s]
#
#
#
#
#
#
#
#
#
#  22%|████████████████▉                                                           | 9915/44601 [00:01<01:19, 436.43it/s]
#
#
#
#
#
#
#
#
#
#  24%|██████████████████▎                                                        | 10861/44601 [00:01<00:55, 611.39it/s]
#
#
#
#
#
#
#
#
#
#  27%|████████████████████                                                       | 11931/44601 [00:01<00:38, 852.53it/s]
#
#
#
#
#
#
#
#
#
#  29%|█████████████████████▌                                                    | 12975/44601 [00:01<00:26, 1176.33it/s]
#
#
#
#
#
#
#
#
#
#  31%|███████████████████████▏                                                  | 13964/44601 [00:01<00:19, 1598.17it/s]
#
#
#
#
#
#
#
#
#
#  34%|████████████████████████▉                                                 | 15014/44601 [00:01<00:13, 2142.61it/s]
#
#
#
#
#
#
#
#
#
#  36%|██████████████████████████▋                                               | 16071/44601 [00:01<00:10, 2816.17it/s]
#
#
#
#
#
#
#
#
#
#  38%|████████████████████████████▎                                             | 17091/44601 [00:01<00:07, 3595.44it/s]
#
#
#
#
#
#
#
#
#
#  41%|██████████████████████████████▏                                           | 18162/44601 [00:02<00:05, 4490.26it/s]
#
#
#
#
#
#
#
#
#
#  43%|███████████████████████████████▊                                          | 19196/44601 [00:02<00:04, 5283.37it/s]
#
#
#
#
#
#
#
#
#
#  45%|█████████████████████████████████▌                                        | 20235/44601 [00:02<00:03, 6197.06it/s]
#
#
#
#
#
#
#
#
#
#  48%|███████████████████████████████████▏                                      | 21242/44601 [00:02<00:03, 6994.43it/s]
#
#
#
#
#
#
#
#
#
#  50%|████████████████████████████████████▉                                     | 22284/44601 [00:02<00:02, 7759.60it/s]
#
#
#
#
#
#
#
#
#
#  52%|██████████████████████████████████████▊                                   | 23372/44601 [00:02<00:02, 8489.95it/s]
#
#
#
#
#
#
#
#
#
#  55%|████████████████████████████████████████▍                                 | 24410/44601 [00:02<00:02, 8910.78it/s]
#
#
#
#
#
#
#
#
#
#  57%|██████████████████████████████████████████▏                               | 25439/44601 [00:02<00:02, 8979.64it/s]
#
#
#
#
#
#
#
#
#
#  59%|███████████████████████████████████████████▊                              | 26434/44601 [00:02<00:02, 9023.23it/s]
#
#
#
#
#
#
#
#
#
#  61%|█████████████████████████████████████████████▍                            | 27404/44601 [00:02<00:01, 9109.99it/s]
#
#
#
#
#
#
#
#
#
#  64%|███████████████████████████████████████████████▏                          | 28444/44601 [00:03<00:01, 9461.72it/s]
#
#
#
#
#
#
#
#
#
#  66%|████████████████████████████████████████████████▊                         | 29427/44601 [00:03<00:01, 9140.39it/s]
#
#
#
#
#
#
#
#
#
#  68%|██████████████████████████████████████████████████▌                       | 30443/44601 [00:03<00:01, 9423.96it/s]
#
#
#
#
#
#
#
#
#
#  70%|████████████████████████████████████████████████████                      | 31408/44601 [00:03<00:01, 8444.00it/s]
#
#
#
#
#
#
#
#
#
#  73%|█████████████████████████████████████████████████████▊                    | 32455/44601 [00:03<00:01, 8963.98it/s]
#
#
#
#
#
#
#
#
#
#  75%|███████████████████████████████████████████████████████▍                  | 33385/44601 [00:03<00:01, 8905.42it/s]
#
#
#
#
#
#
#
#
#
#  77%|████████████████████████████████████████████████████████▉                 | 34338/44601 [00:03<00:01, 9058.26it/s]
#
#
#
#
#
#
#
#
#
#  79%|██████████████████████████████████████████████████████████▋               | 35364/44601 [00:03<00:00, 9387.62it/s]
#
#
#
#
#
#
#
#
#
#  81%|████████████████████████████████████████████████████████████▎             | 36318/44601 [00:03<00:00, 8818.08it/s]
#
#
#
#
#
#
#
#
#
#  83%|█████████████████████████████████████████████████████████████▊            | 37218/44601 [00:04<00:00, 8691.38it/s]
#
#
#
#
#
#
#
#
#
#  86%|███████████████████████████████████████████████████████████████▍          | 38262/44601 [00:04<00:00, 9151.05it/s]
#
#
#
#
#
#
#
#
#
#  88%|█████████████████████████████████████████████████████████████████▏        | 39305/44601 [00:04<00:00, 9474.83it/s]
#
#
#
#
#
#
#
#
#
#  90%|██████████████████████████████████████████████████████████████████▊       | 40267/44601 [00:04<00:00, 6190.99it/s]
#
#
#
#
#
#
#
#
#
#  92%|████████████████████████████████████████████████████████████████████      | 41043/44601 [00:04<00:00, 5012.76it/s]
#
#
#
#
#
#
#
#
#
#  93%|█████████████████████████████████████████████████████████████████████▏    | 41690/44601 [00:04<00:00, 4616.57it/s]
#
#
#
#
#
#
#
#
#
#  95%|██████████████████████████████████████████████████████████████████████    | 42260/44601 [00:05<00:00, 4183.97it/s]
#
#
#
#
#
#
#
#
#
#  96%|██████████████████████████████████████████████████████████████████████▉   | 42762/44601 [00:05<00:00, 4008.26it/s]
#
#
#
#
#
#
#
#
#
#  97%|███████████████████████████████████████████████████████████████████████▊  | 43287/44601 [00:05<00:00, 4314.24it/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████████████████████████████████████████████████████████████████████| 44601/44601 [00:05<00:00, 8059.43it/s]

# %%
import numpy as np 
df['distance'] = df['distance'].apply(lambda x: np.nan if x >= 100 else x) 
df.head()
# Out:
#    borough   neighborhood               building_category  block_id  lot_id  \
# 0      1.0  ALPHABET CITY       03 THREE FAMILY DWELLINGS     377.0    66.0
# 1      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    23.0
# 2      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    26.0
# 3      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
# 4      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
#
#                       address  zip_code  res_units  comm_units  total_units  \
# 0         243 EAST 7TH STREET   10009.0        3.0         0.0          3.0
# 1      262 EAST 7TH STREET, 4   10009.0        4.0         0.0          4.0
# 2         268 EAST 7TH STREET   10009.0        4.0         0.0          4.0
# 3  278 EAST 7TH STREET, 1B/2B   10009.0       19.0         0.0         19.0
# 4  278 EAST 7TH STREET, 1C/1D   10009.0       19.0         0.0         19.0
#
#   square_ft  year_built  tax_class building_class_id  sale_price   sale_date  \
# 0     2,381      1899.0        1.0                C0     4350000   7/16/2020
# 1     2,059      1900.0        2.0                C3      600000  12/12/2019
# 2     2,065      1900.0        2.0                C3     4350000  10/31/2019
# 3     2,772      1920.0        2.0                C4      290000    2/7/2020
# 4     2,772      1920.0        2.0                C4        2500   2/11/2020
#
#     latitude  longitude    age  distance
# 0  40.723987 -73.978167  121.0  6.845256
# 1  40.723384 -73.977590  120.0  6.906150
# 2  40.723276 -73.977386  120.0  6.916168
# 3  40.723106 -73.977057  100.0  6.931970
# 4  40.723106 -73.977057  100.0  6.931970

# %%
df.to_csv("test_data.csv", index = False)

# %%
## PARSE OUT SALE PRICE DATA INTO CATEGORIES

def price_parse(x):
    if x <= 1000000:
        return '0-1m'
    elif x > 1000000 and x <= 10000000:
        return '1m-10m'
    elif x > 10000000 and x <= 100000000:
        return '10m-100m'
    elif x > 100000000:
        return '100m+'
    else:
        return 'na'
##Put categorized sale price data in df
df['cat_price'] = df['sale_price'].apply(lambda x: price_parse(x))

# %%
df['square_ft'] = df['square_ft'].str.replace(',', '')

# %%
df_num = df[['sale_price', 'distance', 'res_units', 'comm_units', 'total_units','age', 'square_ft']].astype(float)

# %%
df = df[(df['sale_price'] > ((100000))) & (df['sale_price'] < ((1000000)))]

# %%
#df_num = df_num.reset_index(drop=True)

# %%
for i, col in enumerate(df_num.columns):
    plt.figure(i)
    sns.distplot(df_num[col].dropna())

# %%
# from scipy.stats import skew
# skewed = df[df_num.columns].apply(lambda x: skew(x.dropna().astype(float)))
# skewed = skewed[skewed > 0.75]
# skewed = skewed.index
# df[skewed] = np.log1p(df[skewed].astype(float))

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(df[df_num.columns].dropna())
# scaled = scaler.transform(df[df_num.columns])


# for i, col in enumerate(df_num.columns):
#     print(i)
#     df_num[col] = scaled[:,i]

# %%
# df_num['sale_price'] = df_num['sale_price'].apply(lambda x: np.log1p(x))
# df_num['square_ft'] = df_num['square_ft'].apply(lambda x: np.log1p(x))
for i in df_num:
    df_num[i] = df_num[i].apply(lambda x: np.log1p(x))

# %%
df.head()
# Out:
#     borough   neighborhood               building_category  block_id  lot_id  \
# 1       1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    23.0
# 3       1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
# 19      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    31.0
# 21      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    41.0
# 22      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0    41.0
#
#                        address  zip_code  res_units  comm_units  total_units  \
# 1       262 EAST 7TH STREET, 4   10009.0        4.0         0.0          4.0
# 3   278 EAST 7TH STREET, 1B/2B   10009.0       19.0         0.0         19.0
# 19     278 EAST 7TH STREET, 5B   10009.0       19.0         0.0         19.0
# 21     745 EAST 6TH STREET, 3C   10009.0       28.0         0.0         28.0
# 22     745 EAST 6TH STREET, 2D   10009.0       28.0         0.0         28.0
#
#     ... year_built  tax_class  building_class_id sale_price   sale_date  \
# 1   ...     1900.0        2.0                 C3     600000  12/12/2019
# 3   ...     1920.0        2.0                 C4     290000    2/7/2020
# 19  ...     1920.0        2.0                 C4     125375   3/13/2020
# 21  ...     1900.0        2.0                 C4     625000   9/12/2019
# 22  ...     1900.0        2.0                 C4     585000    2/6/2020
#
#      latitude  longitude    age  distance  cat_price
# 1   40.723384 -73.977590  120.0   6.90615       0-1m
# 3   40.723106 -73.977057  100.0   6.93197       0-1m
# 19  40.723106 -73.977057  100.0   6.93197       0-1m
# 21  40.722866 -73.977274  120.0   6.96043       0-1m
# 22  40.722866 -73.977274  120.0   6.96043       0-1m
#
# [5 rows x 21 columns]

# %%
for i, col in enumerate(df_num.columns):
    plt.figure(i)
    sns.distplot(df_num[col].dropna())

# %%
corr = df_num.dropna().corr()
cmap = sns.diverging_palette(220,10,as_cmap=True)
sns.heatmap(corr,vmax=.3,center=0,cmap=cmap,square=True, linewidth=.5, cbar_kws={"shrink":.5})
# Out:
# <AxesSubplot:>

# %%
from datetime import datetime

strDate = '7/16/2020'
df1 = df.copy()
df1['sale_date'] = df['sale_date'].apply(lambda x: datetime.strptime(x, '%m/%d/%Y'))

# %%
df1.head()
d1 = datetime(2020, 3, 1)
df['date'] = pd.to_datetime(df['sale_date'])
df['day'] = (df['date'] - d1).dt.days

# %%
df_cat = df[['borough', 'neighborhood', 'building_category', 'cat_price']]

# %%
##Rename Buroughs
def borough_parser(x):
    if x == 1:
        return 'Manhattan'
    elif x == 2:
        return 'Bronx'
    elif x == 3:
        return 'Brooklyn'
    elif x == 4:
        return 'Queens'
    elif x == 5:
        return 'Staten Island'
    else: 
        return 'na'

df_cat['borough'] = df['borough'].apply(lambda x: borough_parser(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
df_cat.head()
# Out:
#       borough   neighborhood               building_category cat_price
# 1   Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS      0-1m
# 3   Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS      0-1m
# 19  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS      0-1m
# 21  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS      0-1m
# 22  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS      0-1m

# %%
for i in df_cat.columns:
    chart = sns.barplot(x=df_cat[i].value_counts()[:20].index,y=df_cat[i].value_counts()[:20], data=df_cat)
    print("Bar Graph for %s total = %d" % (i,len(df_cat[i].value_counts()[:20])))
    chart.set_xticklabels(chart.get_xticklabels(),rotation=75,fontweight='light',
    fontsize='x-small',horizontalalignment='right')
    plt.show()
# Out:
# Bar Graph for borough total = 5
# Bar Graph for neighborhood total = 20
# Bar Graph for building_category total = 20
# Bar Graph for cat_price total = 1

# %%
df.corr()
# Out:
#               borough  block_id    lot_id  zip_code  res_units  comm_units  \
# borough      1.000000  0.348482 -0.179083  0.504307  -0.018481   -0.070421
# block_id     0.348482  1.000000 -0.185817  0.565834  -0.010905   -0.038736
# lot_id      -0.179083 -0.185817  1.000000 -0.095881  -0.007123    0.002598
# zip_code     0.504307  0.565834 -0.095881  1.000000  -0.013473   -0.041887
# res_units   -0.018481 -0.010905 -0.007123 -0.013473   1.000000    0.041850
# comm_units  -0.070421 -0.038736  0.002598 -0.041887   0.041850    1.000000
# total_units -0.023756 -0.013681 -0.010008 -0.017567   0.992145    0.166404
# year_built   0.114124 -0.099708  0.446973 -0.074397  -0.001409    0.014123
# tax_class   -0.326641 -0.306325  0.331992 -0.093629   0.009608    0.164746
# sale_price  -0.093677 -0.096176  0.027437 -0.025717   0.000681   -0.019965
# latitude     0.027228 -0.044437 -0.033015  0.007411   0.001073    0.004371
# longitude   -0.034883  0.071474 -0.012991  0.029967  -0.001051   -0.010164
# age         -0.114124  0.099708 -0.446973  0.074397   0.001409   -0.014123
# distance     0.721633  0.557921 -0.188916  0.209657  -0.013362   -0.067894
# day         -0.020941 -0.008020  0.022544  0.014513  -0.000299    0.034816
#
#              total_units  year_built  tax_class  sale_price  latitude  \
# borough        -0.023756    0.114124  -0.326641   -0.093677  0.027228
# block_id       -0.013681   -0.099708  -0.306325   -0.096176 -0.044437
# lot_id         -0.010008    0.446973   0.331992    0.027437 -0.033015
# zip_code       -0.017567   -0.074397  -0.093629   -0.025717  0.007411
# res_units       0.992145   -0.001409   0.009608    0.000681  0.001073
# comm_units      0.166404    0.014123   0.164746   -0.019965  0.004371
# total_units     1.000000   -0.002302   0.020835   -0.001261  0.001694
# year_built     -0.002302    1.000000   0.247196    0.026617 -0.060490
# tax_class       0.020835    0.247196   1.000000   -0.155595 -0.023008
# sale_price     -0.001261    0.026617  -0.155595    1.000000  0.010654
# latitude        0.001694   -0.060490  -0.023008    0.010654  1.000000
# longitude      -0.002062   -0.006865  -0.016574   -0.003564 -0.464723
# age             0.002302   -1.000000  -0.247196   -0.026617  0.060490
# distance       -0.018207    0.118543  -0.405695   -0.109027 -0.711562
# day             0.003281    0.021102   0.047254   -0.003591 -0.009216
#
#              longitude       age  distance       day
# borough      -0.034883 -0.114124  0.721633 -0.020941
# block_id      0.071474  0.099708  0.557921 -0.008020
# lot_id       -0.012991 -0.446973 -0.188916  0.022544
# zip_code      0.029967  0.074397  0.209657  0.014513
# res_units    -0.001051  0.001409 -0.013362 -0.000299
# comm_units   -0.010164 -0.014123 -0.067894  0.034816
# total_units  -0.002062  0.002302 -0.018207  0.003281
# year_built   -0.006865 -1.000000  0.118543  0.021102
# tax_class    -0.016574 -0.247196 -0.405695  0.047254
# sale_price   -0.003564 -0.026617 -0.109027 -0.003591
# latitude     -0.464723  0.060490 -0.711562 -0.009216
# longitude     1.000000  0.006865 -0.230614  0.002542
# age           0.006865  1.000000 -0.118543 -0.021102
# distance     -0.230614 -0.118543  1.000000 -0.028153
# day           0.002542 -0.021102 -0.028153  1.000000

# %%
df['borough'] = df_cat['borough']
for i in df_num:
    df[i] = df_num[i]

# %%
df.head()
# Out:
#       borough   neighborhood               building_category  block_id  \
# 1   Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0
# 3   Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0
# 19  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0
# 21  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0
# 22  Manhattan  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS     376.0
#
#     lot_id                     address  zip_code  res_units  comm_units  \
# 1     23.0      262 EAST 7TH STREET, 4   10009.0   1.609438         0.0
# 3     31.0  278 EAST 7TH STREET, 1B/2B   10009.0   2.995732         0.0
# 19    31.0     278 EAST 7TH STREET, 5B   10009.0   2.995732         0.0
# 21    41.0     745 EAST 6TH STREET, 3C   10009.0   3.367296         0.0
# 22    41.0     745 EAST 6TH STREET, 2D   10009.0   3.367296         0.0
#
#     total_units  ...  building_class_id  sale_price   sale_date   latitude  \
# 1      1.609438  ...                 C3   13.304687  12/12/2019  40.723384
# 3      2.995732  ...                 C4   12.577640    2/7/2020  40.723106
# 19     2.995732  ...                 C4   11.739073   3/13/2020  40.723106
# 21     3.367296  ...                 C4   13.345509   9/12/2019  40.722866
# 22     3.367296  ...                 C4   13.279369    2/6/2020  40.722866
#
#     longitude       age  distance  cat_price       date  day
# 1  -73.977590  4.795791  2.067641       0-1m 2019-12-12  -80
# 3  -73.977057  4.615121  2.070901       0-1m 2020-02-07  -23
# 19 -73.977057  4.615121  2.070901       0-1m 2020-03-13   12
# 21 -73.977274  4.795791  2.074483       0-1m 2019-09-12 -171
# 22 -73.977274  4.795791  2.074483       0-1m 2020-02-06  -24
#
# [5 rows x 23 columns]

# %%
corr = df.dropna().corr()
cmap = sns.diverging_palette(220,10,as_cmap=True)
sns.heatmap(corr,vmax=.3,center=0,cmap=cmap,square=True, linewidth=.5, cbar_kws={"shrink":.5})
# Out:
# <AxesSubplot:>

# %%
df.to_csv("explored_data.csv", index = False)
